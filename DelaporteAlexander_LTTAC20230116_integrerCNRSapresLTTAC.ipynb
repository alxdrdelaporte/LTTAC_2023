# %% [markdown]
# # ~~Infiltrer~~ Intégrer le CNRS après un Master LTTAC

# %%
# RISE
# Theme : black, night, solarized, MOON

# %%
from IPython.display import Code
xml_s109 = """<S id="S109">
    <AUDIO end="301.79" start="299.42" />
    <FORM kindOf="phono">nɯ ɕɯŋgɯ tɕe, ɯ-kɯ-rga pɯ-dɤn.</FORM>
    <DOI>https://doi.org/10.24397/pangloss-0003490#S109</DOI>
</S>"""

# %%
import re
def nettoyage_extreme(api):
    """Supprimer les balises, signes de ponctuation, chiffres et double-espaces
    Paramètre = api, chaîne de caractères (str)"""
    api = api.replace("$_i$", "")
    api = api.replace("$_j$", "")
    api = api.replace("$_k$", "")
    api = api.replace("ʰ", "h")
    # supprimer balises LaTeX
    balise = re.compile("(\\\\|\r|\n).+?\{", re.IGNORECASE | re.MULTILINE | re.DOTALL)
    api = re.sub(balise, "", api)
    api = api.replace("}", "")
    api = api.replace('\r', "")
    api = api.replace('\n', " ")
    mini_api = api
    # /!\ si retour à une comparaison en nombre de caractères, remettre " " dans la liste
    # ajouter "-" à la liste si besoin (ici pertinent de ne pas le supprimer)
    caracteres = ['"', '.', ",", ";", "(", ")", "/", "@", "<", ">",
                  "?", "!", "_", "~", "…", '\t', "`", "'", "[", "]"]
    for c in caracteres:
        mini_api = mini_api.replace(c, "")
    # supprimer chiffres
    mini_api = re.sub(r'\d+', '', mini_api)
    # supprimer espaces multiples
    mini_api = re.sub(r'\s+', ' ', mini_api)
    return mini_api

# %%
latex = """
\\begin{exe} 
    \ex \label{ex:tWZo.tWkWpe}
    \gll  kɯ-pe tú-wɣ-nɤma tɕe li tɯʑo tɯ-kɯ-pe tu \\
    \textsc{sbj}:\textsc{pcp}-be.good \textsc{ipfv}-\textsc{inv}-make \textsc{lnk} again \textsc{genr} \textsc{genr}.\textsc{poss}-\textsc{sbj}:\textsc{pcp}-be.good exist:\textsc{fact} \\
    \glt  `If one does good things, one will also have good things.' (140518 mao he laoshu-zh, 124)
\end{exe}
"""

# %%
latex_doi = """
\\begin{exe} 
    \ex \label{ex:tWZo.tWkWpe}
    \gll  kɯ-pe tú-wɣ-nɤma tɕe li tɯʑo tɯ-kɯ-pe tu \\
    \textsc{sbj}:\textsc{pcp}-be.good \textsc{ipfv}-\textsc{inv}-make \textsc{lnk} again \textsc{genr} \textsc{genr}.\textsc{poss}-\textsc{sbj}:\textsc{pcp}-be.good exist:\textsc{fact} \\
    \glt  `If one does good things, one will also have good things.' (140518 mao he laoshu-zh, 124)
(https://doi.org/10.24397/pangloss-0004030#S111)
\end{exe}
"""

# %% [markdown]
# **Alexander Delaporte**\
# Centre de recherches linguistiques sur l'Asie orientale
#
# alexander.delaporte@cnrs.fr\
# [tekipaki.hypotheses.org](https://tekipaki.hypotheses.org)

# %% [markdown]
# ## Mon parcours

# %%
import csv
cv_data_path = "./cv_data.tsv"
with open(cv_data_path, "r", encoding="utf-8") as cv:
    cv_reader = csv.DictReader(cv, delimiter="\t")
    print("FORMATION")
    # print("EXPÉRIENCE PROFESSIONNELLE")
    for row in cv_reader:
        if row['TYPE'] == "form":
            print(f"{row['DATE']} : {row['DESCRIPTION']}")

# %% [markdown]
# ## Le métier d'ingénieur d'études
#
# > *Les ingénieures et ingénieurs, les techniciennes et techniciens (IT) du CNRS sont chargés des missions d’accompagnement et d’appui des projets de recherche du CNRS. Ils sont plus de 18 000 au sein du CNRS et exercent plus de 200 métiers différents. Ces métiers sont regroupés par branche d’activités professionnelles (BAP).*

# %% [markdown]
# ## Le métier d'ingénieur d'études
#
# * Métier d'appui à la recherche
#     * Développement/amélioration technique
#     * Valorisation
#     * Administration
#     * Encadrement, enseignement
# * Activité (très) variable selon [BAP](https://metiersit.dsi.cnrs.fr/), fiche de poste, affectation...
# * Accessible sans doctorat
# * Contractuel ou titulaire

# %% [markdown]
# ## Chercher un (premier) emploi
#
# ⚠️ Les sites d'emploi "classiques" sont généralement peu adaptés pour les métiers de la recherche

# %% [markdown]
# * Newsletters / listes de diffusion
# * Réseaux et consortiums
# * Concours externe CNRS

# %% [markdown]
# ### Exemples de listes et réseaux à suivre
#
# **En français**\
# ATALA (liste LN), réseau MATE-SHS, liste de diffusion Digital Humanities (DH), consortiums Huma-Num (CAHIER, CORLI, DISTAM)
#
# **En anglais**\
# Corpora-List, LINGUIST List

# %% [markdown]
# ## Passer le concours externe CNRS
#
# Procédure relativement longue (~ 6 mois)
#
# Trois grandes étapes :
#
# 1. Choisir le(s) concours
# 2. Préparer et soumettre son dossier de candidature
# 3. Passer les épreuves finales d'admission
#
# &#8594; [Guide candidat(e) concours externe CNRS 2022](https://www.cnrs.fr/sites/default/files/download-file/guide_concours_externes_it_V5.pdf)

# %% [markdown]
# ### Choix du concours
#
# * Concours annuel
# * Période d'inscription limitée ([site du concours ITA](https://www.cnrs.fr/fr/concours-it))
# * Postes proposés : BAP, emploi-type, affectation(s)
# * Lecture de la fiche de poste
# * Un poste = un (numéro de) concours

# %% [markdown]
# ### Passation du concours
#
# Avant d'intégrer le concours :
# * Phase d'inscription (inscription en ligne, soumission du dossier de candidature)

# %% [markdown]
# Concours en 2 phases :
# 1. Admissibilité (validation du dossier par le jury)
# 2. Admission (épreuve orale et/ou écrite)

# %% [markdown]
# ### Dossier de candidature
#
# * CV
#     * 1 à 2 pages ([exemple](https://tekipaki.hypotheses.org/a-propos))
# * Lettre(s) de motivation
#     * Une lettre par candidature à un poste
#     * 12 000 caractères maximum
# * Ordre de préférence des concours à préciser
# * Dossier modifiable durant la période d'inscription

# %% [markdown]
# **Validation du dossier &#8594; entrée dans la phase d'admissibilité**

# %% [markdown]
# ### Admissibilité
#
# * Étude des dossiers de candidature par le jury
# * Établissement d'un classement
# * Convocation des candidat(e)s retenu(e)s pour passer l'épreuve d'admission

# %% [markdown]
# **Dossier retenu par le jury &#8594; entrée dans la phase d'admission**

# %% [markdown]
# ### Épreuve d'admission
#
# Ingénieurs (IE et IR) = épreuve écrite facultative
#
# Audition :
# * Exposé (10 minutes)
#     * Respecter strictement le temps imparti
#     * Montrer l'adéquation avec le poste mis au concours
#     * Avec ou sans support visuel
# * Entretien avec le jury (20 minutes)
#     * Anticiper les questions
#     * Si support visuel : prévoir des diapos annexes

# %% [markdown]
# ### Et après le concours ?
#
# * Résultats publics (pour toutes les phases)
# * Notification par courrier postal
# * Si lauréat(e) :
#     * Proposition d'affectation à accepter/refuser sous 15 jours
#     * Prise de fonction au 1<sup>er</sup> décembre (négociable)
#     * Intégration en tant que fonctionnaire stagiaire
#     * Titularisation possible après un an

# %% [markdown]
# ## Un exemple concret d'IE en activité (aka, moi-même)

# %% [markdown]
# ### Le CRLAO
#
# Centre de recherches linguistiques sur l'Asie orientale\
# <small>UMR 8563 CNRS - INALCO - EHESS\
# [site web](http://crlao.ehess.fr/)</small>
#
# * Unité créée en 1960 (*Centre de linguistique chinoise*)
# * Domaine de recherche = linguistique d’Asie orientale, quel que soit le cadre méthodologique ou théorique
# * Seul laboratoire européen dont l'activité est entièrement consacrée à la linguistique d'Asie orientale
# * Dirigé par Huy Linh DAO depuis janvier 2023

# %% [markdown]
# ### Le CRLAO
#
# 4 axes de recherche :
# 1. *Typologie et langues en contact dans l’aire Asie orientale*
# 2. *Syntaxe et sémantique formelles des langues contemporaines d’Asie orientale : chinois, coréen, japonais et vietnamien*
# 3. *Linguistique descriptive des langues d’Asie, phonologie, morphosyntaxe et comparatisme*
# 4. *Écriture chinoise, classification et cognition*

# %% [markdown]
# ### Le CRLAO
#
# 29 membres statutaires :
#
# * 13 chercheurs CNRS
# * 13 enseignants-chercheurs
# * 3 ITA
#
# 42 membres non-statutaires (29 membres associés, 3 postdocs, 10 doctorants)
#
# <small>([Organigramme](http://crlao.ehess.fr/index.php?509))</small>

# %% [markdown]
# ### Mon activité
#
# **Emploi type** = [E2C45](https://metiersit.dsi.cnrs.fr/index.php?page=ficheemploitype&codeEmploi=E2C45&idFamillePro=20&codeBAP=E&codeFamille=C), *Ingénieur-e en ingénierie logicielle*

# %% [markdown]
# ### Mon activité
#
# **Missions**
# > Conception/réalisation de bases de données et corpus, conception et
# développement d’outils et logiciels de consultation et/ou de manipulation  des données, rédaction de la
# documentation technique, maintenance des développements réalisés, formation des utilisateurs

# %% [markdown]
# ### Mon activité
#
# **Activités**
# > Recueil des besoins en développement informatique des membres du laboratoire,
# développement informatique, rédaction de documentation technique, diffusion des développements réalisés  et
# de leur documentation, formation des utilisateurs, veille technologique

# %% [markdown]
# ### Mon activité
#
# **Compétences attendues**
# > Développement informatique, connaissance des techniques de programmation et
# des systèmes de gestion de bases de données, connaissance des technologies web, XML, XSL, familiarité
# avec l’encodage Unicode, maîtrise de langages informatiques (Python, Java...), familiarité avec les systèmes
# d’exploitation Windows, Linux et MacOS, rédaction technique, connaissance de l’anglais technique du
# domaine

# %% [markdown]
# ### Mon activité
#
# **Hors fiche de poste (ou non explicité)**
# * *Correspondant Sécurité des Systèmes d'Information* (CSSI)
#     * Intermédiaire entre membres de l'unité et DSI des tutelles
#     * Inventaire du matériel informatique
#     * Liste de diffusion
# * Membre de différents réseaux, notamment :
#     * Mate-SHS, Mate Condorcet
#     * Consortium DISTAM
#     * GIS Asie

# %% [markdown]
# ## Quelques travaux

# %% [markdown]
# ### *DOI-Mercy*

# %% [markdown]
# ### DOI-Mercy
#
# **Ajout automatique des DOI (*Digital Object Identifiers*) pour les exemples de [*A grammar of Japhug*](https://langsci-press.org/catalog/book/295) de Guilaume Jacques.**
#
# * Programme constitué de 2 sous-programmes développés en Python (3.8)
# * DOI issus du [corpus Japhug](https://pangloss.cnrs.fr/corpus/Japhug?lang=en&mode=pro) sur [Pangloss](https://pangloss.cnrs.fr/) (LACITO)
# * Collaboration avec Séverine Guillaume (coordinatrice Pangloss)

# %% [markdown]
# ### DOI-Mercy
#
# ![grammar_japhug_ex.png](attachment:grammar_japhug_ex.png)

# %%
Code(latex, language="latex")

# %%
exemple1 = "ɯ-mɤ-ku-kɯ-tsʰi"
exemple2 = "[tɤ-rmi ɯ-kɯ-rɤt] tɤ-pɤtso nɯ ɯ-rkɯ ʑo, [...] pjɤ-zɣɯt tɕe,"
exemple3 = "nɯ ma iʑo ji-kɤ-rku me,  atu spɣi tɤ-ɕe qʰe, laχtɕʰa ŋotɕu nɤ-kɤ-sɯso ʑo nɯnɯ, "
exemple4 = "tɕe nɯnɯ ɯ-taʁ jɯ\redp{}jɤ-kɯ-ɣe nɯ ku-ndɤm ɲɯ-ŋu."

# %%
print(f"""{nettoyage_extreme(exemple1)}
{nettoyage_extreme(exemple2)}
{nettoyage_extreme(exemple3)} 
{nettoyage_extreme(exemple4)}""")

# %%
Code(xml_s109, language='xml')

# %%
# Augmenter la largeur du notebook pour confort de lecture du tableau
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# **Fichier de sortie 1 = table de correspondance**
#
# | Flag | Index exemple | Exemple grammaire | Modification grammaire | Fichier grammaire | Phrase corpus | Modification corpus | Fichier corpus | Identifiant | DOI |
# | --- |	--- | --- | --- | --- | --- |	--- | --- | --- | --- |
# | Correspondance  | 7  | nɯ ɕɯŋgɯ tɕe, ɯ-kɯ-rga pɯ-dɤn.  | nɯ ɕɯŋgɯ tɕe ɯ-kɯ-rga pɯ-dɤn  | 4-04.tex  | nɯ ɕɯŋgɯ tɕe, ɯ-kɯ-rga pɯ-dɤn.  | nɯ ɕɯŋgɯ tɕe ɯ-kɯ-rga pɯ-dɤn  | crdo-JYA_HIST-12-ZMBROKO.xml  | S109 | https://doi.org/10.24397/pangloss-0003490#S109 |
# | Imbrication  | 3  | tɤ-mtʰɯm ʁɟa ʑo ma nɯ ma, nɤki, tɯjpu mɤ-kɯ-ndza ci tu tɕe,  | tɤ-mthɯm ʁɟa ʑo ma nɯ ma nɤki tɯjpu mɤ-kɯ-ndza ci tu tɕe  | 4-04.tex  | tɤ-mthɯm ʁɟa ʑo ma nɯ ma, nɤki,  | tɤ-mthɯm ʁɟa ʑo ma nɯ ma nɤki  | crdo-JYA_HIST-27-SPJANKW.xml  | S190 | https://doi.org/10.24397/pangloss-0003704#S190 |
# |   | 5  | a-kɯ-tʰu  |   | 4-04.tex  |   |   |   |  |  |
#
# <small>(ordre des lignes modifié pour l'exemple)</small>

# %% [markdown]
# **Pourquoi 2 sous-programmes ?**
#
# * Vérifier qu'il n'y a pas de problème
# * Quantifier l'automatisation possible
# * Apporter des corrections manuelles
#     * Ajouts manuels pris en compte par le second sous-programme

# %% [markdown]
# **Fichier(s) de sortie 2 = grammaire avec insertion des DOI**

# %%
Code(latex_doi, language="latex")

# %% [markdown]
# <small>Le programme duplique les fichiers d'entrée (fichiers d'origine non altérés).</small>

# %% [markdown]
# ### *Pa-Hng and Hm Nai dialects from Wiktionary*

# %% [markdown]
# ### Pa-Hng and Hm Nai dialects from Wiktionary
#
# **Extraction et restructuration d'un tableau de données issu de la page [Appendix:Pa-Hng comparative vocabulary list](https://en.wiktionary.org/wiki/Appendix:Pa-Hng_comparative_vocabulary_list) du [Wiktionary](https://en.wiktionary.org).**
#
# ![wiktionary_pahng_hmnai.png](attachment:wiktionary_pahng_hmnai.png)

# %% [markdown]
# ### Pa-Hng and Hm Nai dialects from Wiktionary
#
# * Scripts et fichiers [disponibles sur Github](https://github.com/alxdrdelaporte/CRLAO/tree/master/Pa-Hng%20and%20Hm%20Nai%20dialects%20from%20Wiktionary)
# * Fichiers de sortie :
#     * [Tableau extrait non modifié](https://github.com/alxdrdelaporte/CRLAO/blob/master/Pa-Hng%20and%20Hm%20Nai%20dialects%20from%20Wiktionary/Pa-Hng_and_Hm_Nai_dialects_FullTable.tsv)
#     * [Tableau restructuré sans numéros de pages](https://github.com/alxdrdelaporte/CRLAO/blob/master/Pa-Hng%20and%20Hm%20Nai%20dialects%20from%20Wiktionary/Pa-Hng_and_Hm_Nai_dialects.tsv)
#     * [Tableau restructuré avec numéros de pages](https://github.com/alxdrdelaporte/CRLAO/blob/master/Pa-Hng%20and%20Hm%20Nai%20dialects%20from%20Wiktionary/Pa-Hng_and_Hm_Nai_dialects_pageNum.tsv)

# %% [markdown]
# ### Sélecteur langues du monde
#
# **Sélecteur HTML avec une liste de 1193 langues (vivantes, mortes, construites), issue de la page [Liste de langues](https://fr.wikipedia.org/wiki/Liste_de_langues) de [Wikipédia](https://fr.wikipedia.org).**

# %% [markdown]
# * [Tester en ligne](https://alxdrdelaporte.github.io/works/langues_du_monde.html)
# * Sélecteur avec ou sans catégories
# * Code source [disponible sur Github](https://github.com/alxdrdelaporte/CRLAO/tree/master/S%C3%A9lecteur%20langues%20du%20monde)

# %% [markdown]
# ### *AlignWeb*

# %% [markdown]
# ### AlignWeb
#
# **Extraction de contenus textuels web pour constitution de corpus alignés français-japonais, dans le cadre d'un travail de recherche de Raoul Blin.**
#
# * Programme développé en Python (3.10)
# * 2 sous-programmes : corpus XML à partir du web, corpus aligné en texte brut à partir du XML
# * Travail en cours

# %% [markdown]
# ![alignweb01.png](attachment:alignweb01.png)
#
# <font size="2">Cyrille Marlin, « Le sens géographique du jardin « individuel » et sa relation au paysage », *Projets de paysage* [En ligne], 23 | 2020, mis en ligne le 30 décembre 2020, consulté le 09 décembre 2022. <br>URL : http://journals.openedition.org/paysage/12838 ; DOI : https://doi.org/10.4000/paysage.12838</font>

# %% [markdown]
# ![alignweb02.png](attachment:alignweb02.png)

# %% [markdown]
# ![alignweb03.png](attachment:alignweb03.png)

# %% [markdown]
# **Critères d'alignement des segments**
#
# Deux segments d'une même paire sont considérés comme probablement alignés si :
#
# 1. Ils sont issus d'une page dont la version française et la version japonaise ont permis d'extraire le même nombre d'éléments HTML.
# 2. Leurs tags respectifs sont identiques.
# 3. Leurs contenus textuels respectifs n'ont pas une trop grande différence de longueur.
#
# La longueur d'un segment textuel est calculée sur la base du nombre de "mots" : pour le français, ce nombre est calculé en prenant l'espace comme séparateur, pour le japonais il est calculé via [tinysegmenter](https://pypi.org/project/tinysegmenter/).
# La différence de longueur est considérée "trop grande" si le rapport entre le segment le plus long et le segment le plus court est supérieur à 2,5.
#
# Une autre option permet de choisir de comparer la longueur des segments sans parsing, sur la base du nombre de caractères. La différence de longueur est alors considérée "trop grande" si le rapport entre le segment le plus long et le segment le plus court est supérieur à 3.

# %% [markdown]
# `python3 XML2txt.py -sg "p"`
#
# Avec `-sg "p"`, le contenu textuel de chaque segment est à nouveau segmenté suivant les points et points d'interrogation, c'est-à-dire les caractères *.* et *?* pour le français, et *。* et *？* pour le japonais, à condition :
#
# * Qu'au moins un de ces caractères soit présent dans chaque segment de la même paire (parmi les caractères correspondant à leur langue respective).
# * Que chacun des segments de la paire comporte le même nombre de ce(s) caractère(s) de ponctuation.

# %% [markdown]
# ### *Tekipaki*

# %% [markdown]
# ### [*Tekipaki*](https://tekipaki.hypotheses.org/)
#
# **Carnet [Hypothèses](https://fr.hypotheses.org/) pour la diffusion et la valorisation des travaux d'ingénierie informatique réalisés pour le CRLAO.\
# <small>Adossé à des dépôts [Github](https://github.com/alxdrdelaporte?tab=repositories) et [Gitlab](https://gitlab.com/dashboard/groups) + une [page de démo](https://alxdrdelaporte.github.io/)</small>**

# %% [markdown]
# * Partage de scripts :
#     * Issus de projets du laboratoire
#     * "Allégés" et calibrés pour une tâche particulière
#     * Documentés (construction et adaptation)
# * Présentation d'outils d'automatisation
# * Vulgarisation (lexicographie, informatique)
# * Apprentissage de langues asiatiques

# %% [markdown]
# **Exemple : cartographie linguistique avec Python**
#
# Projets du CRLAO :
# * Cartes pour la représentation de données de recherche de membres du laboratoire
# * Notebook Jupyter pour que l'équipe de recherche puisse modifier/créer ses propres cartes sans assistance
# * Cartographie des langues étudiées au CRLAO dans un but de valorisation (projet suspendu, à reprendre prochainement)

# %% [markdown]
# **Exemple : cartographie linguistique avec Python**
#
# Sur [*Tekipaki*](https://tekipaki.hypotheses.org) :
# 1. [Créer une carte à partir de données au format CSV](https://tekipaki.hypotheses.org/1225)
# 2. [Représenter plusieurs séries de données sur une même carte](https://tekipaki.hypotheses.org/1362)
# 3. [Cartographier des données linguistiques sous forme de surface (polygone)](https://tekipaki.hypotheses.org/1414)
# 4. [Automatiser la capture d'écran pour exporter une vue PNG d'une carte HTML](https://tekipaki.hypotheses.org/1418)
# 5. [Créer une carte à partir de données au format GeoJSON](https://tekipaki.hypotheses.org/1421)
#
# \+ notebooks partagés sur Gitlab : [cartographie_linguistique_Python](https://gitlab.com/tekipaki-blog/cartographie_linguistique_python)\
# \+ cartes partagées sur page Github : [une série de points](https://alxdrdelaporte.github.io/works/carte_hmongmien_points.html), [deux séries de points](https://alxdrdelaporte.github.io/works/carte_hmongmien_japonic.html), [choix de fond de carte](https://alxdrdelaporte.github.io/works/carte_japonic_layer-control.html), [polygone](https://alxdrdelaporte.github.io/works/carte_hmongmien_polygone.html)

# %% [markdown]
# **Exemple : cartographie linguistique avec Python**
#
# Pour faire suite : cartographie linguistique avec R.
#
# * [Article sur Tekipaki](https://tekipaki.hypotheses.org/2744)
# * [Répertoire Github](https://github.com/alxdrdelaporte/cartographie_linguistique_R)
# * [Répertoire Gitlab](https://gitlab.com/tekipaki-blog/cartographie_linguistique_R)
# * [Exemple de fichier de sortie : démo](https://alxdrdelaporte.github.io/works/carte_hmongmien_clusters.html)

# %% [markdown]
# ## Contact et infos
#
# N'hésitez pas à me contacter si vous avez des questions.
#
# Voici quelques liens où vous trouverez des informations complémentaires :
#
# * **Passer du Master LTTAC à un poste d'IE CNRS**
#     * [Interview sur *Lilagora*](https://www.lilagora.fr/group/faculte-des-humanites/30/articles/et-toi-qu-est-ce-que-tu-as-fait-apres-tes-etudes-9/14/10/2022/1009)
#     * [CV sur *Tekipaki*](https://tekipaki.hypotheses.org/a-propos)
# * **Programmer avec Python**
#     * [*Tekipaki*](https://tekipaki.hypotheses.org)
#     * [TP 2021 : *Cartographie linguistique*](https://github.com/alxdrdelaporte/LTTAC_2021_TP)
# * **Linguistique des langues d'Asie Orientale**
#     * [Site du CRLAO](http://crlao.ehess.fr/)
